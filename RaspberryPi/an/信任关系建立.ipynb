# %%
ansible-playbook ssh_openkey_to_all.ymal
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [删除临时目录temp] ********************************************************
# changed: [localhost]
#
# TASK [生成临时目录temp] ********************************************************
# changed: [localhost]
#
# TASK [传输文件到临时目录] ******************************************************
# changed: [localhost]
#
# PLAY [all] *********************************************************************
#
# TASK [生成 openkey] ************************************************************
# ok: [workerc]
# ok: [workerb]
# ok: [master]
# ok: [workera]
# ok: [adm]
#
# TASK [由于.ssh目录无法fetch] ***************************************************
# changed: [workerc]
# changed: [workerb]
# changed: [master]
# changed: [workera]
# changed: [adm]
#
# TASK [取得public key] **********************************************************
# changed: [workerb]
# changed: [workerc]
# changed: [master]
# changed: [workera]
# changed: [adm]
#
# ...
